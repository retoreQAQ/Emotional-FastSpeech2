# %%
'''
构造raw_data，等同于prepare_align.py
'''
import os
import sys
import argparse
import json
import yaml
import librosa
import numpy as np
from scipy.io import wavfile

sys.path.append('/home/you/workspace/son/FastSpeech2')
from text import _clean_text


def split_json_by_splitset(input_file, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Load the JSON file
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Group data by Split_Set
    split_data = {}
    for key, value in data.items():
        split_set = value.get("Split_Set", "Unknown")
        if split_set not in split_data:
            split_data[split_set] = {}
        split_data[split_set][key] = value

    # Save each group to a separate JSON file
    for split_set, items in split_data.items():
        output_file = os.path.join(output_dir, f"{split_set}.json")
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(items, f, indent=4, ensure_ascii=False)

    print(f"Data has been split and saved into {output_dir}")


def copy_files_from_list(config, part_file):
    in_dir = config["path"]["corpus_path"]
    out_dir = config["path"]["raw_path"]
    sampling_rate = config["preprocessing"]["audio"]["sampling_rate"]
    max_wav_value = config["preprocessing"]["audio"]["max_wav_value"]
    cleaners = config["preprocessing"]["text"]["text_cleaners"]
    data_part_path = os.path.join(in_dir, 'Labels', part_file)
    if not os.path.exists(data_part_path):
        split_json_by_splitset(os.path.join(in_dir, 'Labels', 'labels_consensus.json'), os.path.join(in_dir, 'Labels'))
    
    
    # Ensure output directories exist
    os.makedirs(out_dir, exist_ok=True)

    # Load the JSON file
    with open(data_part_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Get the list of keys (audio file names)
    for audio_file, metadata in data.items():
        speaker_id = metadata.get("SpkrID", "unknown")
        speaker_folder = os.path.join(out_dir, speaker_id)
        os.makedirs(speaker_folder, exist_ok=True)
    
        wav_path = os.path.join(os.path.join(in_dir, 'Audios'), audio_file)
        if os.path.exists(wav_path):
            wav, _ = librosa.load(wav_path, sampling_rate)
            epsilon = 1e-6  # 小常数，防止分母过小
            wav = wav / (np.max(np.abs(wav)) + epsilon) * max_wav_value
            wav_output_path = os.path.join(speaker_folder, audio_file)
            wavfile.write(wav_output_path, sampling_rate, wav.astype(np.int16))
        
        base_name = os.path.splitext(audio_file)[0]
        transcript_file = base_name + '.txt'
        transcript_path = os.path.join(os.path.join(in_dir, 'Transcripts'), transcript_file)
        if os.path.exists(transcript_path):
            with open(transcript_path, 'r', encoding='utf-8') as f:
                text = f.read()
            cleaned_text = _clean_text(text, cleaners)
            transcript_output_path = os.path.join(speaker_folder, base_name + ".lab")
            with open(transcript_output_path, 'w', encoding='utf-8') as f:
                f.write(cleaned_text)

    print(f"Files have been copied to {out_dir}")
        
        

config = yaml.load(open('/home/you/workspace/son/FastSpeech2/config/MSP/preprocess.yaml', "r"), Loader=yaml.FullLoader)
part_files = ['Development.json', 'Train.json', 'Test1.json', 'Test2.json']
part_file = part_files[1]
copy_files_from_list(config, part_file)
# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("config", type=str, help="path to preprocess.yaml")
#     args = parser.parse_args()

#     config = yaml.load(open(args.config, "r"), Loader=yaml.FullLoader)
#     copy_files_from_list(config)
# Out:
# Files have been copied to /home/you/workspace/son/FastSpeech2/raw_data/MSP

# %%
import shutil
import yaml, json
def trans_textgrid(config, part_file):
    '''
    part_file对应的textgrid文件转移到/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP
    '''
    in_dir = config["path"]["corpus_path"]
    out_dir = config["path"]["preprocessed_path"]
    out_dir = os.path.join(out_dir, 'TextGrid')
    data_part_path = os.path.join(in_dir, 'Labels', part_file)
    if not os.path.exists(data_part_path):
        split_json_by_splitset(os.path.join(in_dir, 'Labels', 'labels_consensus.json'), os.path.join(in_dir, 'Labels'))
    # Ensure output directories exist
    os.makedirs(out_dir, exist_ok=True)
    # Load the JSON file
    with open(data_part_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    for audio_file, metadata in data.items():
        speaker_id = metadata.get("SpkrID", "unknown")
        speaker_folder = os.path.join(out_dir, speaker_id)
        os.makedirs(speaker_folder, exist_ok=True)
        base_name = os.path.splitext(audio_file)[0]
        textgrid_file_name = base_name + '.TextGrid'
        textgrid_path = os.path.join(os.path.join(in_dir, 'ForceAligned'), textgrid_file_name)
        if os.path.exists(textgrid_path):
            shutil.copy(textgrid_path, os.path.join(speaker_folder, textgrid_file_name))
        

config = yaml.load(open('/home/you/workspace/son/FastSpeech2/config/MSP/preprocess.yaml', "r"), Loader=yaml.FullLoader)
trans_textgrid(config, part_file)

# %%
'''
textgrid文件有些是空的，会导致preprocess.py报错，这里检测并处理。
'''
import os
import tgt

# 输入路径
textgrid_folder = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid"
raw_data_folder = "/home/you/workspace/son/FastSpeech2/raw_data"

n = 0
for root, dirs, files in os.walk(textgrid_folder):
    for file in files:
        tg_path = os.path.join(root, file)
        try:
            # 尝试读取 TextGrid 文件
            textgrid = tgt.io.read_textgrid(tg_path)
        except Exception as e:
            # 处理错误
            print(f"Error processing TextGrid: {tg_path}")
            
            # 删除出错的 TextGrid 文件
            os.remove(tg_path)
            print(f"Deleted TextGrid: {tg_path}")
            
            # 提取 basename 和 spkrID
            basename = os.path.splitext(file)[0]
            spkrID = os.path.basename(root)  # 获取上级目录名作为 spkrID
            
            # 构造对应的 .wav 和 .lab 文件路径
            wav_path = os.path.join(raw_data_folder, 'MSP', spkrID, f"{basename}.wav")
            lab_path = os.path.join(raw_data_folder, 'MSP', spkrID, f"{basename}.lab")
            
            # 删除 .wav 文件
            if os.path.exists(wav_path):
                os.remove(wav_path)
                print(f"Deleted WAV: {wav_path}")
            
            # 删除 .lab 文件
            if os.path.exists(lab_path):
                os.remove(lab_path)
                print(f"Deleted LAB: {lab_path}")
            
            n += 1
print(n)
# Out:
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3258/MSP-PODCAST_5730_1301.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3258/MSP-PODCAST_5730_1301.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3258/MSP-PODCAST_5730_1301.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3258/MSP-PODCAST_5730_1301.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2430/MSP-PODCAST_5748_0066.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2430/MSP-PODCAST_5748_0066.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2430/MSP-PODCAST_5748_0066.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2430/MSP-PODCAST_5748_0066.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3234/MSP-PODCAST_5718_0589.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3234/MSP-PODCAST_5718_0589.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3234/MSP-PODCAST_5718_0589.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3234/MSP-PODCAST_5718_0589.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3193/MSP-PODCAST_5685_0298.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3193/MSP-PODCAST_5685_0298.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3193/MSP-PODCAST_5685_0298.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3193/MSP-PODCAST_5685_0298.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3251/MSP-PODCAST_5740_0321.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3251/MSP-PODCAST_5740_0321.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3251/MSP-PODCAST_5740_0321.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3251/MSP-PODCAST_5740_0321.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3221/MSP-PODCAST_5707_0456.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3221/MSP-PODCAST_5707_0456.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3221/MSP-PODCAST_5707_0456.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3221/MSP-PODCAST_5707_0456.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3250/MSP-PODCAST_5724_1209.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3250/MSP-PODCAST_5724_1209.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3250/MSP-PODCAST_5724_1209.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3250/MSP-PODCAST_5724_1209.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3279/MSP-PODCAST_5757_0151.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3279/MSP-PODCAST_5757_0151.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3279/MSP-PODCAST_5757_0151.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3279/MSP-PODCAST_5757_0151.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3279/MSP-PODCAST_5762_0871.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3279/MSP-PODCAST_5762_0871.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3279/MSP-PODCAST_5762_0871.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3279/MSP-PODCAST_5762_0871.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3214/MSP-PODCAST_5700_0362.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3214/MSP-PODCAST_5700_0362.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3214/MSP-PODCAST_5700_0362.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3214/MSP-PODCAST_5700_0362.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3214/MSP-PODCAST_5700_0234.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3214/MSP-PODCAST_5700_0234.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3214/MSP-PODCAST_5700_0234.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3214/MSP-PODCAST_5700_0234.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2921/MSP-PODCAST_5526_0396.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2921/MSP-PODCAST_5526_0396.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2921/MSP-PODCAST_5526_0396.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2921/MSP-PODCAST_5526_0396.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3032/MSP-PODCAST_5667_0991.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3032/MSP-PODCAST_5667_0991.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3032/MSP-PODCAST_5667_0991.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3032/MSP-PODCAST_5667_0991.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/263/MSP-PODCAST_5568_0686.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/263/MSP-PODCAST_5568_0686.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/263/MSP-PODCAST_5568_0686.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/263/MSP-PODCAST_5568_0686.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/263/MSP-PODCAST_5575_0603.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/263/MSP-PODCAST_5575_0603.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/263/MSP-PODCAST_5575_0603.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/263/MSP-PODCAST_5575_0603.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2823/MSP-PODCAST_5293_0182.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2823/MSP-PODCAST_5293_0182.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2823/MSP-PODCAST_5293_0182.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2823/MSP-PODCAST_5293_0182.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2889/MSP-PODCAST_5492_2836.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2889/MSP-PODCAST_5492_2836.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2889/MSP-PODCAST_5492_2836.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2889/MSP-PODCAST_5492_2836.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3266/MSP-PODCAST_5744_0892.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3266/MSP-PODCAST_5744_0892.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3266/MSP-PODCAST_5744_0892.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3266/MSP-PODCAST_5744_0892.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2960/MSP-PODCAST_5590_0504_0000.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/2960/MSP-PODCAST_5590_0504_0000.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2960/MSP-PODCAST_5590_0504_0000.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/2960/MSP-PODCAST_5590_0504_0000.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0532_0203.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0532_0203.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0532_0203.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0532_0203.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0443.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0443.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0443.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0443.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0417_0651.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0417_0651.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0417_0651.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0417_0651.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0360_0197.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0360_0197.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0360_0197.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0360_0197.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0865.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0865.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0865.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0865.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_1328.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_1328.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_1328.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_1328.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0086.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0086.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0086.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0086.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0194.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0194.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0194.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0194.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0526_0387.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0526_0387.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0526_0387.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0526_0387.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0285.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0285.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0285.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0285.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0021.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0021.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0021.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0021.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0254_0278.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0254_0278.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0254_0278.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0254_0278.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0367_1135.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0367_1135.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0367_1135.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0367_1135.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0383_2044.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0383_2044.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0383_2044.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0383_2044.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_2218_0892.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_2218_0892.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_2218_0892.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_2218_0892.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0016.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0016.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0016.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0016.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0631_0602.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0631_0602.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0631_0602.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0631_0602.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0004.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0004.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0004.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0004.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0301.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0301.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0301.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0301.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0477.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0477.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0477.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0477.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0299_0185.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0299_0185.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0299_0185.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0299_0185.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0402_2326.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0402_2326.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0402_2326.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0402_2326.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0526_0390.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0526_0390.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0526_0390.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0526_0390.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0515_0046.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0515_0046.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0515_0046.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0515_0046.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_2342_0317.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_2342_0317.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_2342_0317.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_2342_0317.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0110.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0110.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0110.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0110.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0210_0251.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0210_0251.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0210_0251.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0210_0251.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0201_0225.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0201_0225.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0201_0225.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0201_0225.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0312.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0312.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0312.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0312.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0012.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0012.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0012.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0012.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0336_0011.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0336_0011.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0336_0011.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0336_0011.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0103.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0103.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0103.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0103.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0537_0163.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0537_0163.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0537_0163.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0537_0163.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0301_0212.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0301_0212.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0301_0212.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0301_0212.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0235_0077.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0235_0077.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0235_0077.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0235_0077.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0225.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0225.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0225.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0225.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0303.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0303.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0303.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0303.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0749.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0749.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0749.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0749.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0038.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0038.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0038.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0038.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0540_0184.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0540_0184.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0540_0184.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0540_0184.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0222_0140.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0222_0140.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0222_0140.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0222_0140.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0310.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0310.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0310.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0310.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0174.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0174.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0174.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0174.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0535_0225.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0535_0225.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0535_0225.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0535_0225.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0268.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0268.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0268.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0268.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0536_0082.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0536_0082.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0536_0082.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0536_0082.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0517_0034.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0517_0034.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0517_0034.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0517_0034.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0619_0251.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0619_0251.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0619_0251.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0619_0251.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_0014.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_0014.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_0014.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_0014.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0362_0084.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0362_0084.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0362_0084.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0362_0084.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3111_0242.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3111_0242.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3111_0242.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3111_0242.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0344_0533.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0344_0533.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0344_0533.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0344_0533.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0344_0037.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0344_0037.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0344_0037.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0344_0037.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0337.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0337.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0337.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0337.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0243.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0243.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0243.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0243.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0033.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0033.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0033.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0033.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3057_0327.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3057_0327.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3057_0327.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3057_0327.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0548_0457.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0548_0457.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0548_0457.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0548_0457.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0422_0278.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0422_0278.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0422_0278.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0422_0278.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_2810.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_2810.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_2810.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_2810.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_0016.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_0016.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_0016.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_0016.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0099_0003.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0099_0003.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0099_0003.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0099_0003.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0515_0028.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0515_0028.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0515_0028.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0515_0028.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_1326.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0396_1326.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_1326.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0396_1326.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0354_0014.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0354_0014.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0354_0014.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0354_0014.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0104.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0104.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0104.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0104.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0203_0816.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0203_0816.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0203_0816.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0203_0816.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0138.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0138.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0138.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0138.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0421.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0421.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0421.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0421.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0254_0064.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0254_0064.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0254_0064.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0254_0064.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0308_0589.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0308_0589.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0308_0589.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0308_0589.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0027.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0027.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0027.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0027.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0367_1008.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0367_1008.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0367_1008.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0367_1008.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0597.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0326_0597.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0597.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0326_0597.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0013.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0013.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0013.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0013.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0225.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0225.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0225.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0225.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0552_0001.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0552_0001.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0552_0001.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0552_0001.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0181.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0181.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0181.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0181.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_1493.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0253_1493.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_1493.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0253_1493.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0419_0000.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3557_0419_0000.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0419_0000.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3557_0419_0000.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0557_0043.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0557_0043.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0557_0043.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0557_0043.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0514_0075.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0514_0075.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0514_0075.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0514_0075.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0258_0028.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0258_0028.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0258_0028.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0258_0028.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3584_0648_0001.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_3584_0648_0001.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3584_0648_0001.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_3584_0648_0001.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0343_0635.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0343_0635.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0343_0635.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0343_0635.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0088.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0088.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0088.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0088.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0261_0104.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0261_0104.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0261_0104.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0261_0104.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0230_0570.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0230_0570.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0230_0570.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0230_0570.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0603_0301.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0603_0301.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0603_0301.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0603_0301.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0054.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0420_0054.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0054.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0420_0054.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0558_0108.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0558_0108.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0558_0108.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0558_0108.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0353_0086.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0353_0086.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0353_0086.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0353_0086.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0544_0800.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0544_0800.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0544_0800.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0544_0800.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0304.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0627_0304.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0304.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0627_0304.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0222_0143.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0222_0143.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0222_0143.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0222_0143.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0106.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0543_0106.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0106.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0543_0106.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0421.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0541_0421.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0421.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0541_0421.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0070.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0070.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0070.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0070.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0098.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0098.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0098.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0098.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0299.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0421_0299.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0299.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0421_0299.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0433.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0356_0433.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0433.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0356_0433.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0106.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0512_0106.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0106.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0512_0106.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0009.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0256_0009.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0009.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0256_0009.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0009.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0516_0007_0009.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0009.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0516_0007_0009.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0574_0031.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0574_0031.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0574_0031.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0574_0031.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0273_0014.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0273_0014.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0273_0014.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0273_0014.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0203_1962.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0203_1962.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0203_1962.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0203_1962.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0106.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0528_0106.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0106.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0528_0106.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0551_0105_0014.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0551_0105_0014.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0551_0105_0014.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0551_0105_0014.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0079.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0616_0079.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0079.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0616_0079.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0567_0138.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0567_0138.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0567_0138.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0567_0138.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0251_0389.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/Unknown/MSP-PODCAST_0251_0389.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0251_0389.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/Unknown/MSP-PODCAST_0251_0389.lab
# Error processing TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3249/MSP-PODCAST_5734_0739.TextGrid
# Deleted TextGrid: /home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/3249/MSP-PODCAST_5734_0739.TextGrid
# Deleted WAV: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3249/MSP-PODCAST_5734_0739.wav
# Deleted LAB: /home/you/workspace/son/FastSpeech2/raw_data/MSP/3249/MSP-PODCAST_5734_0739.lab

# %%
'''获取最长序列长度'''
import os
import librosa

def get_max_seqlength(audio_folder, sampling_rate=22050):
    max_length = 0  # 最大序列长度
    max_file = None  # 最大文件名

    for root, dirs, files in os.walk(audio_folder):  # 遍历所有目录和次级目录
        for file in files:
            if file.endswith(".wav"):  # 只处理 .wav 文件
                file_path = os.path.join(root, file)  # 获取完整路径
                try:
                    # 加载音频文件
                    wav, sr = librosa.load(file_path, sr=sampling_rate)
                    length = len(wav)  # 获取采样点数
                    if length > max_length:
                        max_length = length
                        max_file = file_path
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

    # 转换为秒（可选）
    max_length_in_seconds = max_length / sampling_rate

    print(f"Max sequence length: {max_length} samples ({max_length_in_seconds:.2f} seconds)")
    print(f"Longest file: {max_file}")

# 使用示例
audio_folder = "/home/you/workspace/son/FastSpeech2/raw_data/MSP"  # 顶级目录
get_max_seqlength(audio_folder, sampling_rate=22050)
# Out:
# Max sequence length: 247042 samples (11.20 seconds)
# Longest file: /home/you/workspace/son/FastSpeech2/raw_data/MSP/67/MSP-PODCAST_0285_0018.wav

# %%
'''删除非ARPAbet音素的textgrid文件'''
import os
import re
import tgt

# ARPAbet音素的正则表达式
ARPABET_PATTERN = re.compile(r"^[A-Z]+[0-2]?$")  # 大写字母+可选的重音数字（0, 1, 2）

def is_arpabet_sequence(text):
    """
    判断给定文本是否是有效的 ARPAbet 音素
    """
    return ARPABET_PATTERN.match(text) is not None

def delete_non_arpabet_textgrids(textgrid_folder):
    """
    删除 `phones` 层级中包含非 ARPAbet 音素序列的 TextGrid 文件
    """
    for root, dirs, files in os.walk(textgrid_folder):
        num = 0
        for file in files:
            if file.endswith(".TextGrid"):
                tg_path = os.path.join(root, file)
                try:
                    # 加载 TextGrid 文件
                    textgrid = tgt.io.read_textgrid(tg_path)
                    
                    # 检查是否存在 "phones" 层级
                    if "phones" in textgrid.get_tier_names():
                        tier = textgrid.get_tier_by_name("phones")
                        # phones = get_alignment(tier)
                        # print(phones)
                        # 遍历所有间隔，检查是否存在非 ARPAbet 音素
                        contains_non_arpabet = any(
                            not is_arpabet_sequence(interval.text.strip()) for interval in tier.intervals if interval.text.strip()
                        )
                        
                        if contains_non_arpabet:
                            # print(f"Deleting file with non-ARPAbet phonemes: {tg_path}")
                            os.remove(tg_path)
                            # 提取 basename 和 spkrID
                            basename = os.path.splitext(file)[0]
                            spkrID = os.path.basename(root)  # 获取上级目录名作为 spkrID
                            
                            # 构造对应的 .wav 和 .lab 文件路径
                            wav_path = os.path.join(raw_data_folder, 'MSP', spkrID, f"{basename}.wav")
                            lab_path = os.path.join(raw_data_folder, 'MSP', spkrID, f"{basename}.lab")
                            
                            # 删除 .wav 文件
                            if os.path.exists(wav_path):
                                os.remove(wav_path)
                                # print(f"Deleted WAV: {wav_path}")
                            
                            # 删除 .lab 文件
                            if os.path.exists(lab_path):
                                os.remove(lab_path)
                                # print(f"Deleted LAB: {lab_path}")
                            num += 1
                except Exception as e:
                    print(f"Error processing {tg_path}: {e}")
    
    print(f"Deleted {num} non-ARPAbet TextGrid files.")


def get_alignment(tier):
    sil_phones = ["sil", "sp", "spn"]

    phones = []
    for t in tier._objects:
        s, e, p = t.start_time, t.end_time, t.text

        # Trim leading silences
        if phones == []:
            if p in sil_phones:
                continue
            else:
                start_time = s

        if p not in sil_phones:
            # For ordinary phones
            phones.append(p)
            end_time = e
            end_idx = len(phones)
        else:
            # For silent phones
            phones.append(p)

    # Trim tailing silences
    phones = phones[:end_idx]

    return phones

# 使用示例
textgrid_folder = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/TextGrid/"
delete_non_arpabet_textgrids(textgrid_folder)
# Out:
# Deleted 0 non-ARPAbet TextGrid files.

# %%
'''生成train_labels.json'''
import os
import pandas as pd
import json

# ======== 修改为你的实际路径 ========
audio_root = "/home/you/workspace/son/FastSpeech2/raw_data/MSP"         # wav 所在目录（包含子目录）
csv_path = "/home/you/workspace/database/MSP/Labels/labels_consensus.csv"             # 图1对应的CSV路径
json_out_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train_labels.json"          # 输出json文件名
# ====================================

# 1. 获取所有 .wav 文件名（不带扩展名）
wav_basenames = []
for root, _, files in os.walk(audio_root):
    for file in files:
        if file.endswith(".wav"):
            wav_basenames.append(file)

# 2. 加载 CSV，按 FileName 筛选
df = pd.read_csv(csv_path)

# 3. 筛选 CSV 中出现在 .wav 文件中的行
filtered_df = df[df["FileName"].isin(wav_basenames)]

# 4. 转为字典形式，以 FileName 为键
result_dict = filtered_df.set_index("FileName").T.to_dict()

# 5. 保存为 JSON
with open(json_out_path, "w", encoding="utf-8") as f:
    json.dump(result_dict, f, indent=4, ensure_ascii=False)

print(f"完成！共筛选出 {len(result_dict)} 条记录，已保存到：{json_out_path}")
# Out:
# 完成！共筛选出 54786 条记录，已保存到：/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train_labels.json

# %%
'''从train_labels.json提取emotions.json '''
import json
import os
import numpy as np

def generate_emotions_json(train_labels_path, output_path):
    # 读取train_labels.json
    labels_path = train_labels_path
    with open(labels_path, 'r', encoding='utf-8') as f:
        labels = json.load(f)
    
    # 初始化情绪字典
    emotions = set()
    arousals = []
    valences = []
    
    # 从标签中提取情绪信息
    for _, label in labels.items():
        # 情绪类型
        if 'EmoClass' in label:
            emotions.add(label['EmoClass'])
        # 唤醒度 (EmoAct)
        if 'EmoAct' in label:
            arousals.append(float(label['EmoAct']))
        # 效价 (EmoVal)
        if 'EmoVal' in label:
            valences.append(float(label['EmoVal']))
    
    # 创建情绪类型映射字典
    emotion_dict = {emotion: idx for idx, emotion in enumerate(sorted(emotions))}
    
    # 对唤醒度和效价进行分箱处理
    n_bins = 14  # 与模型配置保持一致
    arousal_min, arousal_max = min(arousals), max(arousals)
    valence_min, valence_max = min(valences), max(valences)
    
    # 创建分箱边界
    arousal_bins = np.linspace(arousal_min, arousal_max, n_bins-1)
    valence_bins = np.linspace(valence_min, valence_max, n_bins-1)
    
    # 创建映射字典
    arousal_dict = {str(round(bin_val, 1)): idx for idx, bin_val in enumerate(arousal_bins)}
    valence_dict = {str(round(bin_val, 1)): idx for idx, bin_val in enumerate(valence_bins)}
    
    # 组合成最终的emotions.json结构
    emotions_json = {
        "emotion_dict": emotion_dict,
        "arousal_dict": arousal_dict,
        "valence_dict": valence_dict,
        "arousal_bins": arousal_bins.tolist(),  # 保存分箱边界，供后续使用
        "valence_bins": valence_bins.tolist()   # 保存分箱边界，供后续使用
    }
    
    # 保存到emotions.json
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(emotions_json, f, indent=2)
    
    print(f"已生成 emotions.json，包含：")
    print(f"- 情绪类型数量: {len(emotion_dict)}")
    print(f"- 唤醒度分箱数量: {len(arousal_dict)}")
    print(f"- 效价分箱数量: {len(valence_dict)}")
    print(f"\n唤醒度范围: [{arousal_min:.1f}, {arousal_max:.1f}]")
    print(f"效价范围: [{valence_min:.1f}, {valence_max:.1f}]")

if __name__ == "__main__":
    train_labels_path = '/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train_labels.json'
    output_path = '/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/emotions.json'
    generate_emotions_json(train_labels_path, output_path)

# %%
'''生成添加了情绪信息的train/val.txt，使用前改原文件名为train_orignal.txt/val_orignal.txt'''
import json

def round_half(x):
    return round(x * 2) / 2

# ======= 修改路径为你的真实路径 =======
train_orignal_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train_original.txt"
val_orignal_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/val_original.txt"
train_labels_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train_labels.json"
output_train_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train.txt"
output_val_path = "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/val.txt"
# =====================================

# 读取 JSON 数据（文件 B）
with open(train_labels_path, "r", encoding="utf-8") as f:
    emotion_data = json.load(f)
def process_emotion_file(input_path, output_path, emotion_data):
    """处理情绪标注文件
    
    Args:
        input_path (str): 输入文件路径(train_orignal.txt或val_orignal.txt)
        output_path (str): 输出文件路径(train.txt或val.txt) 
        emotion_data (dict): 情绪标注数据
    """
    with open(input_path, "r", encoding="utf-8") as fin, open(output_path, "w", encoding="utf-8") as fout:
        for line in fin:
            line = line.strip()
            if not line:
                continue
            parts = line.split("|")
            if len(parts) < 3:
                continue

            utt_id = parts[0]
            wav_key = utt_id + ".wav"

            if wav_key in emotion_data:
                emo = emotion_data[wav_key]
                emo_class = emo.get("EmoClass", "NA")
                emo_act = emo.get("EmoAct", "NA")
                emo_val = emo.get("EmoVal", "NA")
                emo_act = round_half(emo.get("EmoAct", 0))
                emo_val = round_half(emo.get("EmoVal", 0))
                # 添加到行尾
                new_line = f"{line}|{emo_class}|{emo_act}|{emo_val}\n"
            else:
                # 如果不在 JSON 中，也保留原始行
                new_line = f"{line}|NA|NA|NA\n"
                print(f'{line}')

            fout.write(new_line)
    
    print(f"✅ 合并完成，输出保存至：{output_path}")

# process_emotion_file(train_orignal_path, output_train_path, emotion_data)
process_emotion_file(val_orignal_path, output_val_path, emotion_data)
# Out:
# ✅ 合并完成，输出保存至：/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/val.txt

# %%
'''合并LibriTTS和MSP的speakers.json'''
import json
import shutil
shutil.move("/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/speakers.json", "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/original_speakers.json")

with open("/home/you/workspace/son/FastSpeech2/preprocessed_data/LibriTTS/speakers.json") as f:
    libri_spk = json.load(f)
with open("/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/original_speakers.json") as f:
    msp_spk = json.load(f)

# 添加前缀，重新编号
merged_spk = {}
cur_id = 0

for name in libri_spk:
    merged_spk[f"LibriTTS_{name}"] = cur_id
    cur_id += 1

for name in msp_spk:
    merged_spk[f"MSP_{name}"] = cur_id
    cur_id += 1

with open("/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/speakers.json", "w") as f:
    json.dump(merged_spk, f, indent=4)

# %%
'''为speaker id添加前缀'''
import os

def add_prefix_to_speaker(line, dataset_name):
    parts = line.strip().split('|')
    if len(parts) >= 2:
        speaker_id = parts[1]
        # 根据数据集名称添加对应前缀
        parts[1] = f"{dataset_name}_{speaker_id}"
    return '|'.join(parts)

def process_file(file_path):
    temp_path = file_path + '.temp'
    # 从文件路径判断数据集名称
    dataset_name = os.path.basename(os.path.dirname(file_path))
    
    with open(file_path, 'r', encoding='utf-8') as fin:
        with open(temp_path, 'w', encoding='utf-8') as fout:
            for line in fin:
                new_line = add_prefix_to_speaker(line, dataset_name)
                fout.write(new_line + '\n')
    
    # 替换原文件
    os.replace(temp_path, file_path)
    print(f"✅ 已完成{os.path.basename(file_path)}中{dataset_name}数据集的speaker id前缀添加")

# 要处理的文件列表
files_to_process = [
    "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/train.txt",
    "/home/you/workspace/son/FastSpeech2/preprocessed_data/MSP/val.txt",
    "/home/you/workspace/son/FastSpeech2/preprocessed_data/LibriTTS/train.txt",
    "/home/you/workspace/son/FastSpeech2/preprocessed_data/LibriTTS/val.txt"
]

# 批量处理所有文件
for file_path in files_to_process:
    if os.path.exists(file_path):
        process_file(file_path)
    else:
        print(f"⚠️ 文件不存在: {file_path}")
# Out:
# ✅ 已完成val.txt中MSP数据集的speaker id前缀添加
# ✅ 已完成train.txt中LibriTTS数据集的speaker id前缀添加
# ✅ 已完成val.txt中LibriTTS数据集的speaker id前缀添加
